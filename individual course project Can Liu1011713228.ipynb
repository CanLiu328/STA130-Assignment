# %%
# the CSCS webpage (https://casch.org/cscs) or the course github and access them locally
# "https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv"
# "https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv"

import pandas as pd
cols = pd.read_csv("var_names.csv")
data = pd.read_csv("CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only
dataV2 = data[data.REMOVE_case=='No'].copy()
dataV2_cohort = dataV2[dataV2.SURVEY_cohort_participant].copy()
dataV2_cohortV2 = dataV2_cohort[dataV2_cohort.SURVEY_collection_year!=2023].copy()
missingness_limit = 100 # this retains 166 of 1024 columns that aren't fully empty
columns2keep = dataV2_cohortV2.isna().sum() < missingness_limit
columns2keep = columns2keep.index[columns2keep]
dataV2_cohortV3 = dataV2_cohortV2[columns2keep].copy()
# The data itself then looks like this
pd.set_option('display.max_columns', dataV2_cohortV3.shape[1]) # Can cause jupyter notebooks to crash
# DO NOT USE in conjuection with pd.set_option('display.max_rows', 1000) 
dataV2_cohortV3
# Out:
# /tmp/ipykernel_84/3519133812.py:7: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("CSCS_data_anon.csv",
#         UNIQUE_id  UNIQUE_num_records ELIGIBLE_consent  \
# 19     cscs_00021                   3              Yes
# 21     cscs_00021                   3              Yes
# 71     cscs_00074                   3              Yes
# 77     cscs_00080                   2              Yes
# 78     cscs_00080                   2              Yes
# ...           ...                 ...              ...
# 11379  cscs_11760                   3              Yes
# 11380  cscs_11760                   3              Yes
# ...

# %% [markdown]
# Research 1

# %% [markdown]
# 1.introduction
# Background:In past few years, with the COVID-19 attacked, numerous people were influenced by it. By doing this research, I want to disclose some relations between the rules that people must obey during pandemic peoriod and the mentality changes occured to people.
# Goal:Given that the data from past three months ago, we would delve into the relationship between social distances and sense of isolated,then to judge if the extent of sense of isolated were improved thus predicting the whole human world the condition of sense of isolated.

# %% [markdown]
# 2.Variable analysis
# (a)Variable type analysis
# COVID_prevention_distancing: This is typically a categorical variable, indicating different levels of adherence to social distancing guidelines (e.g., "strictly following," "partially following," "not following").
# LONELY_ucla_loneliness_scale: This is usually a continuous variable, indicating levels of loneliness measured on a scale (often ranging from a defined minimum to a maximum).
# (b) Descriptive Statistics
# Frequency Distribution for Categorical Variable
# For the categorical variable COVID_prevention_distancing, calculate the frequency and percentage of each category.
# Descriptive Statistics for Continuous Variable
# For the continuous variable LONELY_ucla_loneliness_scale, calculate descriptive statistics like mean, median, and standard deviation.
# (c)Data Visualization
# Bar Plot for Categorical Variable
# To visualize the distribution of COVID_prevention_distancing, a bar plot can be employed.
# Box Plot for Continuous Variable
# To visualize the distribution of LONELY_ucla_loneliness_scale, a box plot can illustrate the median, quartiles, and any outliers.
# Box Plot by Categorical Variable
# To analyze how COVID_prevention_distancing affects loneliness, a box plot can be created to show the loneliness levels across different distancing categories.

# %% [markdown]
# 3.Analysis Methods
# (a)Correlation Analysis
# Analyzing Correlation
# To evaluate whether there is a statistical relationship between COVID_prevention_distancing and LONELY_ucla_loneliness_scale, we can perform an ANOVA test, especially since one variable is categorical and the other is continuous.
# (b)Hypothesis Testing
# Formulating Hypotheses
# Based on the analysis, we can formulate hypotheses regarding the relationship between the two variables:
# Null Hypothesis (H0): There is no significant difference in loneliness levels across different COVID prevention distancing categories.
# Alternative Hypothesis (H1): There is a significant difference in loneliness levels across different COVID prevention distancing categories.
# (c)Summary and Interpretation
# Interpretation of Results: After performing the ANOVA test, check the p-value in the ANOVA table to determine if the null hypothesis can be rejected. A p-value less than 0.05 typically indicates a statistically significant difference between groups.
# Visual Insights: The box plot and bar plot visualizations provide insight into how social distancing behavior may influence reported loneliness levels, helping identify trends or patterns in the data.

# %% [markdown]
# 4.Inference
# Inference:social distance would make a influence on sense of isolated.
# Hypothesis 1: Individuals with higher values of COVID_prevention_distancing (or who more frequently adhere to social distancing measures) tend to have higher scores on the LONELY_ucla_loneliness_scale_isolated, suggesting that social distancing measures may lead to increased feelings of loneliness.
#
# Hypothesis 2: Attitudes or behaviors regarding COVID_prevention_distancing may vary across different age groups (e.g., younger individuals may be less likely to adhere to social distancing measures than older individuals).

# %% [markdown]
# 5.Meaning
# The experiment can raise awareness about the mental health implications of social distancing and highlight the importance of mental well-being in the context of public health. This can lead to a broader societal conversation about the need for mental health resources and support during times of crisis.

# %% [markdown]
# Research 2

# %% [markdown]
# 1.Goal:delve into the relationship between life satisfication and ectent of helpless as well as burnout.

# %% [markdown]
# 2.Variable Analysis
# WELLNESS_life_satisfaction:it is a numerical variable, which indicates in a form of number the extent of satification.
# we can choose to use histogram to represent it.
# Purpose: A histogram displays the distribution of the data, helping to observe the frequency of different life satisfaction values. This method is suitable for examining the central tendency, skewness, and overall shape of the distribution.
# Process:
# Divide the data into several intervals (also known as “bins”), where each interval represents a range of life satisfaction scores.
# Count the number of data points that fall within each interval and plot these counts as bars.
# WELLNESS_malach_pines_burnout_measure_helpless：it is a categorical variable.
# Descriptive Statistics
# Next, calculate descriptive statistics to summarize the variable’s characteristics. This typically includes:
#
# Mean
# Median
# Standard deviation
# Minimum and maximum values
# Quartiles
# This information will give insights into the central tendency and variability of the burnout measure.
# ox Plot
# Purpose: A box plot summarizes the distribution of the burnout scores, highlighting the median, quartiles, and potential outliers.
# Process:
# Draw a box that represents the interquartile range (IQR), extending from the lower quartile to the upper quartile.
# Indicate the median with a line inside the box and draw whiskers to show the range of the data.
# Mark any outliers beyond the whiskers.

# %% [markdown]
# 3.Analysis methods
# Once we have a grasp of each variable, we can visualize their relationship using the following methods:
#
# a. Scatter Plot
# Purpose: A scatter plot can show the relationship between the two variables, helping to identify any trends, patterns, or correlations.
# Process:
# Plot WELLNESS_life_satisfaction on the x-axis and WELLNESS_malach_pines_burnout_measure_helpless on the y-axis.
# Observe the spread of points to see if there’s a visible trend (e.g., positive, negative, or no correlation).
# b. Correlation Analysis
# Purpose: Calculate the correlation coefficient (e.g., Pearson or Spearman) to quantify the strength and direction of the relationship.
# Process:
# Calculate the correlation coefficient to determine how strongly the two variables are related. A value close to 1 or -1 indicates a strong relationship, while a value close to 0 indicates a weak relationship.
# c. Regression Analysis
# Purpose: If a relationship is observed, you may perform regression analysis to explore how well one variable predicts the other.
# Process:
# Fit a linear regression model using one variable as the predictor and the other as the response variable.
# Examine the regression coefficients and the goodness of fit (e.g., R-squared value) to understand the predictive power of the model.
# 3. Interpretation of Results
# After conducting the visualizations and analyses, interpret the findings:
#
# Strength of Relationship: Assess the correlation coefficient to determine if a strong or weak relationship exists. A negative correlation may suggest that higher life satisfaction is associated with lower levels of helplessness in burnout.
# Trends: Look for trends in the scatter plot. For instance, if the points tend to slope downwards, it indicates that as life satisfaction increases, helplessness in burnout decreases.
# Significance: If performed regression analysis, check the p-values of the coefficients to see if the relationship is statistically significant.

# %% [markdown]
# 4.Inference
# Negative Correlation:
#
# If the analysis reveals a significant negative correlation between the two variables, we can infer that higher life satisfaction is associated with lower levels of helplessness in burnout. This suggests that individuals who report greater satisfaction with their lives may feel more in control and less overwhelmed by stressors contributing to burnout.

# %% [markdown]
# 5.Conclusion
# Raising Awareness of Mental Health
# By exploring the relationship between life satisfaction and feelings of burnout, the research can enhance societal awareness of mental health issues. In today’s fast-paced and high-pressure environment, understanding these relationships helps reduce the stigma surrounding mental health problems and promotes public recognition of their importance.

# %% [markdown]
# Research 3

# %% [markdown]
# 1.Goal：delve into the relationship between social supports and mental health.

# %% [markdown]
# 2.Variable analysis
# The variable of social support is classified into categories (e.g., "Low," "Medium," "High"), it would be of type object or category (categorical).
# Creating a Count Plot
# Step 1: Import Libraries
# Step 2: Prepare Your Data
# Step 3: Create the Count Plot
# Bars: Represent the count of each category in the Social Support variable.
# Height of Bars: Indicates the frequency of each category.
#
# The variable of mental helath is divided into categories (e.g., "Normal," "Moderate," "Severe"), it would be of type object or category (categorical).
# we can use histogram to visualize this data.
# Bars: Each bar represents the frequency of data points within the range defined by its bin.
# Height of Bars: Indicates the number of observations falling within that bin's range.
# Shape of Distribution: we can analyze the overall distribution shape (e.g., normal, skewed) and identify peaks (modalities).

# %% [markdown]
# 3.Analysis methods
# Step 1: Import Libraries
# Start by ensuring we have the necessary libraries for data analysis.
#
# Step 2: Prepare Your Data
# Clean the dataset by removing any entries with missing values for the Social Support and Mental Health variables.
#
# Step 3: Exploratory Data Analysis
# Visualize the relationship between Social Support and Mental Health using a scatter plot. This will help identify any apparent trends or correlations between the two variables.
#
# Step 4: Fit the Linear Regression Model
# Define the independent variable (Social Support) and the dependent variable (Mental Health). Use statistical software to fit a linear regression model, which involves calculating the best-fitting line through the data points.
#
# Step 5: Review the Model Summary
# Examine the results of the regression analysis. Look for key statistics such as coefficients, R-squared values, and p-values. The coefficients indicate the direction and magnitude of the relationship between the variables.
#
# Step 6: Visualize the Regression Line
# Create a plot that shows both the scatter plot of the data points and the fitted regression line. This visual representation helps to illustrate the relationship between Social Support and Mental Health.

# %% [markdown]
# 4.Inference
# Coefficients: Interpret the coefficients to understand how changes in Social Support are expected to affect Mental Health scores.
# R-squared: Evaluate how much of the variance in Mental Health is explained by Social Support. A value close to 1 indicates a good fit.
# P-value: Check the p-value for the Social Support coefficient. A value less than 0.05 indicates a statistically significant relationship.
# Confidence Intervals: Review the confidence intervals for the coefficients to understand the range in which the true parameters likely fall.
# Example Output Interpretation
# If the coefficient for Social Support is positive, it indicates that increases in social support are associated with improvements in mental health.
# If the R-squared value is 0.35, it suggests that 35% of the variability in Mental Health scores can be explained by Social Support.
# A significant p-value indicates a meaningful relationship, suggesting that social support is an important predictor of mental health.

# %% [markdown]
# 5.Meaning
# Promoting Community Well-Being: Understanding the importance of social support can encourage initiatives that strengthen community ties, leading to improved mental health for community members.
# Reducing Stigma: Highlighting the role of social support in mental health can help reduce stigma around seeking help, encouraging individuals to reach out for assistance and support.
